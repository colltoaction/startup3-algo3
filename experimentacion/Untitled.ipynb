# %% [markdown]
# # Experimentacion para el algoritmo genético

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import sys
sys.path.append('/usr/local/lib/python2.7/dist-packages')
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import random

# %%
# !cd ../genetico && make experimentarFitness
# Out:
# g++ -std=c++11 -pedantic -Wall -O4 -DFITNESS -DFITNESSONE -DOUTPUTBEST main_test.cpp -o ricardofort.o && ./ricardofort.o 2> ../experimentacion/fitness.out

# %%
dfResultados = pd.read_csv('./fitness.out', delimiter=";")
dfVariance = dfResultados.groupby('Generacion').var()
dfMean = dfResultados.groupby('Generacion').mean()

ax = dfMean.plot(logy=False)
ax.set_ylabel("Media de la Fitness")
ax.set_xlabel("Generacion")
plt.title("Media de la Fitness en funcion de la generacion")
plt.show()


ax = dfVariance.plot(logy=False)
ax.set_ylabel("Varianza de la Fitness")
ax.set_xlabel("Generacion")
plt.title("Varianza de la Fitness en funcion de la generacion")
plt.show()

# %%
# !cd ../genetico && make experimentarFitness2
# Out:
# g++ -std=c++11 -pedantic -Wall -O4 -DFITNESS -DFITNESSTWO -DOUTPUTBEST main_test.cpp -o ricardofort.o && ./ricardofort.o 2> ../experimentacion/fitness2.out

# %%
dfResultadosFitness2 = pd.read_csv('./fitness2.out', delimiter=";")
dfVariance = dfResultadosFitness2.groupby('Generacion').var()
dfMean = dfResultadosFitness2.groupby('Generacion').mean()

ax = dfMean.plot(logy=False)
ax.set_ylabel("Media de la Fitness")
ax.set_xlabel("Generacion")
plt.title("Media de la Fitness en funcion de la generacion")
plt.show()


ax = dfVariance.plot(logy=False)
ax.set_ylabel("Varianza de la Fitness")
ax.set_xlabel("Generacion")
plt.title("Varianza de la Fitness en funcion de la generacion")
plt.show()

# %% [markdown]
# # Experimentacion Correlacion de Genes

# %%
# !cd ../genetico && make experimentarCorrelacionGenes

# %%
dfResultados = pd.read_csv('./geneweights.out', delimiter=";")
plt.rcParams["figure.figsize"] = (30,30)

sns.heatmap(dfResultados.corr(), annot=True)
plt.show()

# %% [markdown]
# # Experimento NonLinearities

# %%
# !cd ../genetico && make experimentarNonLinear
# Out:
# g++ -std=c++11 -pedantic -Wall -O4 -DFITNESS -DFITNESSONE -DOUTPUTBEST -DNONLINEAR main_test.cpp -o ricardofort.o && ./ricardofort.o 2> ../experimentacion/fitnessNonLinear.out
# In file included from matingpool.h:1:0,
#                  from main_test.cpp:2:
# genome.h: In constructor ‘Genome::Genome(int)’:
# genome.h:411:32: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (unsigned int i = 0; i < bound; ++i) {
#                                 ^
# genome.h: In member function ‘float Genome::activate(Board, int)’:
# genome.h:439:32: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (unsigned int i = 0; i < bound; ++i) {
#                                 ^
# In file included from main_test.cpp:2:0:
# matingpool.h: In lambda function:
# matingpool.h:75:41: error: ‘this’ was not captured for this lambda function
#                  auto res1 = minimax(m1, plays-1, false);
#                                          ^
# matingpool.h:75:41: error: invalid use of non-static data member ‘PlayerMinimax_n::plays’
# matingpool.h:65:9: note: declared here
#      int plays;
#          ^
# matingpool.h:78:41: error: ‘this’ was not captured for this lambda function
#                  auto res2 = minimax(m2, plays-1, false);
#                                          ^
# matingpool.h:78:41: error: invalid use of non-static data member ‘PlayerMinimax_n::plays’
# matingpool.h:65:9: note: declared here
#      int plays;
#          ^
# In file included from main_test.cpp:2:0:
# matingpool.h: In member function ‘void MatingPool::newGeneration()’:
# matingpool.h:211:70: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#     if (currentGeneration % extinctionRate == 0 || currentGeneration < extinctio
#                                                                      ^
# matingpool.h: In member function ‘void MatingPool::evolvePopulation(unsigned int, int)’:
# matingpool.h:228:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#              for (int i = 0; i < populationSize; ++i) {
#                                ^
# matingpool.h: In member function ‘float MatingPool::calculateFitness(Genome)’:
# matingpool.h:272:74: error: invalid initialization of non-const reference of type ‘Player&’ from an rvalue of type ‘Player’
#          pair<int,int > result = game.playMatch(player, PlayerMinimax_n(3));
#                                                                           ^
# In file included from ../common/player_random.h:2:0,
#                  from genome.h:3,
#                  from matingpool.h:1,
#                  from main_test.cpp:2:
# ../common/judge.h:599:19: note:   initializing argument 2 of ‘std::pair<int, int> Game::playMatch(Player&, Player&)’
#      pair<int,int> playMatch(Player& playerOne, Player& playerTwo) {
#                    ^
# In file included from main_test.cpp:2:0:
# matingpool.h:269:13: warning: unused variable ‘champion’ [-Wunused-variable]
#          int champion = rand() % lastChampions.size();
#              ^
# In file included from /usr/include/c++/5/bits/stl_algobase.h:71:0,
#                  from /usr/include/c++/5/bits/char_traits.h:39,
#                  from /usr/include/c++/5/ios:40,
#                  from /usr/include/c++/5/ostream:38,
#                  from /usr/include/c++/5/iostream:39,
#                  from main_test.cpp:1:
# /usr/include/c++/5/bits/predefined_ops.h: In instantiation of ‘bool __gnu_cxx::__ops::_Iter_comp_iter<_Compare>::operator()(_Iterator1, _Iterator2) [with _Iterator1 = __gnu_cxx::__normal_iterator<PossibleMove*, std::vector<PossibleMove> >; _Iterator2 = __gnu_cxx::__normal_iterator<PossibleMove*, std::vector<PossibleMove> >; _Compare = PlayerMinimax_n::nextMove(Game&)::<lambda(const PossibleMove&, const PossibleMove&)>]’:
# /usr/include/c++/5/bits/stl_algo.h:5490:12:   required from ‘_ForwardIterator std::__max_element(_ForwardIterator, _ForwardIterator, _Compare) [with _ForwardIterator = __gnu_cxx::__normal_iterator<PossibleMove*, std::vector<PossibleMove> >; _Compare = __gnu_cxx::__ops::_Iter_comp_iter<PlayerMinimax_n::nextMove(Game&)::<lambda(const PossibleMove&, const PossibleMove&)> >]’
# /usr/include/c++/5/bits/stl_algo.h:5539:43:   required from ‘_FIter std::max_element(_FIter, _FIter, _Compare) [with _FIter = __gnu_cxx::__normal_iterator<PossibleMove*, std::vector<PossibleMove> >; _Compare = PlayerMinimax_n::nextMove(Game&)::<lambda(const PossibleMove&, const PossibleMove&)>]’
# matingpool.h:82:13:   required from here
# /usr/include/c++/5/bits/predefined_ops.h:123:46: error: void value not ignored as it ought to be
#          { return bool(_M_comp(*__it1, *__it2)); }
#                                               ^
# Makefile:24: recipe for target 'experimentarNonLinear' failed
# make: *** [experimentarNonLinear] Error 1

# %%
dfResultadosFitness2 = pd.read_csv('./fitnessNonLinear.out', delimiter=";")
dfVariance = dfResultadosFitness2.groupby('Generacion').var()
dfMean = dfResultadosFitness2.groupby('Generacion').mean()

ax = dfMean.plot(logy=False)
ax.set_ylabel("Media de la Fitness")
ax.set_xlabel("Generacion")
plt.title("Media de la Fitness en funcion de la generacion")
plt.show()


ax = dfVariance.plot(logy=False)
ax.set_ylabel("Varianza de la Fitness")
ax.set_xlabel("Generacion")
plt.title("Varianza de la Fitness en funcion de la generacion")
plt.show()
